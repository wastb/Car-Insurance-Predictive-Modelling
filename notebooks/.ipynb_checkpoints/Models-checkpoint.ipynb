# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

from scipy.stats import f_oneway
from scipy.stats import ttest_ind

from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import OneHotEncoder
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score,  mean_absolute_error
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor
import xgboost as xgb
import shap


import sys
sys.path.append("../scripts")

import preprocessing as dp
import data_extraction as de
import exploratory_analysis as eda

# %% [markdown]
# ### ***Load Data***

# %%
df = de.load_data('../data/csv.csv')
# Out:
# d:\Personal Files\KIAM Notebooks\KIAM-Week3\notebooks\../scripts\data_extraction.py:11: DtypeWarning: Columns (4) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(
# Data Loaded Successfully

# %%
df.head()
# Out:
#    UnderwrittenCoverID  PolicyID TransactionMonth  IsVATRegistered  \
# 0               145249     12827    3/1/2015 0:00             True
# 1               145249     12827    5/1/2015 0:00             True
# 2               145249     12827    7/1/2015 0:00             True
# 3               145255     12827    5/1/2015 0:00             True
# 4               145255     12827    7/1/2015 0:00             True
#
#   Citizenship          LegalType Title Language                 Bank  \
# 0         NaN  Close Corporation    Mr  English  First National Bank
# 1         NaN  Close Corporation    Mr  English  First National Bank
# 2         NaN  Close Corporation    Mr  English  First National Bank
# 3         NaN  Close Corporation    Mr  English  First National Bank
# 4         NaN  Close Corporation    Mr  English  First National Bank
#
#        AccountType  ...                    ExcessSelected CoverCategory  \
# 0  Current account  ...             Mobility - Windscreen    Windscreen
# 1  Current account  ...             Mobility - Windscreen    Windscreen
# 2  Current account  ...             Mobility - Windscreen    Windscreen
# 3  Current account  ...  Mobility - Metered Taxis - R2000    Own damage
# 4  Current account  ...  Mobility - Metered Taxis - R2000    Own damage
#
#     CoverType            CoverGroup              Section  \
# 0  Windscreen  Comprehensive - Taxi  Motor Comprehensive
# 1  Windscreen  Comprehensive - Taxi  Motor Comprehensive
# 2  Windscreen  Comprehensive - Taxi  Motor Comprehensive
# 3  Own Damage  Comprehensive - Taxi  Motor Comprehensive
# 4  Own Damage  Comprehensive - Taxi  Motor Comprehensive
#
#                            Product StatutoryClass StatutoryRiskType  \
# 0  Mobility Metered Taxis: Monthly     Commercial     IFRS Constant
# 1  Mobility Metered Taxis: Monthly     Commercial     IFRS Constant
# 2  Mobility Metered Taxis: Monthly     Commercial     IFRS Constant
# 3  Mobility Metered Taxis: Monthly     Commercial     IFRS Constant
# 4  Mobility Metered Taxis: Monthly     Commercial     IFRS Constant
#
#    TotalPremium TotalClaims
# 0     21.929825           0
# 1     21.929825           0
# 2      0.000000           0
# 3    512.848070           0
# 4      0.000000           0
#
# [5 rows x 52 columns]

# %% [markdown]
# ### ***Data Preprocessing***

# %%
## Initialize the pre processing class

data_preprocessing = dp.DataPreprocessing(df)

# %%
## Drop Highly empty columns
data_preprocessing.drop_highly_empty_columns()
# Out:
# Highly empty columns dropped: ['Citizenship', 'CustomValueEstimate', 'WrittenOff', 'Rebuilt', 'Converted', 'CrossBorder', 'NumberOfVehiclesInFleet']
#          UnderwrittenCoverID  PolicyID TransactionMonth  IsVATRegistered  \
# 0                     145249     12827    3/1/2015 0:00             True
# 1                     145249     12827    5/1/2015 0:00             True
# 2                     145249     12827    7/1/2015 0:00             True
# 3                     145255     12827    5/1/2015 0:00             True
# 4                     145255     12827    7/1/2015 0:00             True
# ...                      ...       ...              ...              ...
# 1000093                31520       389    4/1/2015 0:00            False
# 1000094                31520       389    6/1/2015 0:00            False
# 1000095                31520       389    8/1/2015 0:00            False
# 1000096                31519       389    7/1/2014 0:00            False
# 1000097                31519       389    2/1/2015 0:00            False
#
#                  LegalType Title Language                 Bank  \
# 0        Close Corporation    Mr  English  First National Bank
# 1        Close Corporation    Mr  English  First National Bank
# 2        Close Corporation    Mr  English  First National Bank
# 3        Close Corporation    Mr  English  First National Bank
# 4        Close Corporation    Mr  English  First National Bank
# ...                    ...   ...      ...                  ...
# 1000093         Individual    Mr  English            ABSA Bank
# 1000094         Individual    Mr  English            ABSA Bank
# 1000095         Individual    Mr  English            ABSA Bank
# 1000096         Individual    Mr  English            ABSA Bank
# 1000097         Individual    Mr  English            ABSA Bank
#
#              AccountType  MaritalStatus  ...  \
# 0        Current account  Not specified  ...
# 1        Current account  Not specified  ...
# 2        Current account  Not specified  ...
# 3        Current account  Not specified  ...
# 4        Current account  Not specified  ...
# ...                  ...            ...  ...
# 1000093  Savings account         Single  ...
# 1000094  Savings account         Single  ...
# 1000095  Savings account         Single  ...
# 1000096  Savings account         Single  ...
# 1000097  Savings account         Single  ...
#
#                            ExcessSelected        CoverCategory  \
# 0                   Mobility - Windscreen           Windscreen
# 1                   Mobility - Windscreen           Windscreen
# 2                   Mobility - Windscreen           Windscreen
# 3        Mobility - Metered Taxis - R2000           Own damage
# 4        Mobility - Metered Taxis - R2000           Own damage
# ...                                   ...                  ...
# 1000093                         No excess          Third Party
# 1000094                         No excess          Third Party
# 1000095                         No excess          Third Party
# 1000096                         No excess  Passenger Liability
# 1000097                         No excess  Passenger Liability
#
#                    CoverType            CoverGroup              Section  \
# 0                 Windscreen  Comprehensive - Taxi  Motor Comprehensive
# 1                 Windscreen  Comprehensive - Taxi  Motor Comprehensive
# 2                 Windscreen  Comprehensive - Taxi  Motor Comprehensive
# 3                 Own Damage  Comprehensive - Taxi  Motor Comprehensive
# 4                 Own Damage  Comprehensive - Taxi  Motor Comprehensive
# ...                      ...                   ...                  ...
# 1000093          Third Party  Comprehensive - Taxi  Motor Comprehensive
# 1000094          Third Party  Comprehensive - Taxi  Motor Comprehensive
# 1000095          Third Party  Comprehensive - Taxi  Motor Comprehensive
# 1000096  Passenger Liability  Comprehensive - Taxi  Motor Comprehensive
# 1000097  Passenger Liability  Comprehensive - Taxi  Motor Comprehensive
#
#                                     Product StatutoryClass  StatutoryRiskType  \
# 0           Mobility Metered Taxis: Monthly     Commercial      IFRS Constant
# 1           Mobility Metered Taxis: Monthly     Commercial      IFRS Constant
# 2           Mobility Metered Taxis: Monthly     Commercial      IFRS Constant
# 3           Mobility Metered Taxis: Monthly     Commercial      IFRS Constant
# 4           Mobility Metered Taxis: Monthly     Commercial      IFRS Constant
# ...                                     ...            ...                ...
# 1000093  Mobility Commercial Cover: Monthly     Commercial      IFRS Constant
# 1000094  Mobility Commercial Cover: Monthly     Commercial      IFRS Constant
# 1000095  Mobility Commercial Cover: Monthly     Commercial      IFRS Constant
# 1000096  Mobility Commercial Cover: Monthly     Commercial      IFRS Constant
# 1000097  Mobility Commercial Cover: Monthly     Commercial      IFRS Constant
#
#         TotalPremium  TotalClaims
# 0          21.929825            0
# 1          21.929825            0
# 2           0.000000            0
# 3         512.848070            0
# 4           0.000000            0
# ...              ...          ...
# 1000093   347.235175            0
# 1000094   347.235175            0
# 1000095   347.235175            0
# 1000096     2.315000            0
# 1000097     2.315000            0
#
# [1000098 rows x 45 columns]

# %%
## Impute categorical data with mode
data_preprocessing.impute_categorical_data()
# Out:
#          UnderwrittenCoverID  PolicyID TransactionMonth  IsVATRegistered  \
# 0                     145249     12827    3/1/2015 0:00             True
# 1                     145249     12827    5/1/2015 0:00             True
# 2                     145249     12827    7/1/2015 0:00             True
# 3                     145255     12827    5/1/2015 0:00             True
# 4                     145255     12827    7/1/2015 0:00             True
# ...                      ...       ...              ...              ...
# 1000093                31520       389    4/1/2015 0:00            False
# 1000094                31520       389    6/1/2015 0:00            False
# 1000095                31520       389    8/1/2015 0:00            False
# 1000096                31519       389    7/1/2014 0:00            False
# 1000097                31519       389    2/1/2015 0:00            False
#
#                  LegalType Title Language                 Bank  \
# 0        Close Corporation    Mr  English  First National Bank
# 1        Close Corporation    Mr  English  First National Bank
# 2        Close Corporation    Mr  English  First National Bank
# 3        Close Corporation    Mr  English  First National Bank
# 4        Close Corporation    Mr  English  First National Bank
# ...                    ...   ...      ...                  ...
# 1000093         Individual    Mr  English            ABSA Bank
# 1000094         Individual    Mr  English            ABSA Bank
# 1000095         Individual    Mr  English            ABSA Bank
# 1000096         Individual    Mr  English            ABSA Bank
# 1000097         Individual    Mr  English            ABSA Bank
#
#              AccountType  MaritalStatus  ...  \
# 0        Current account  Not specified  ...
# 1        Current account  Not specified  ...
# 2        Current account  Not specified  ...
# 3        Current account  Not specified  ...
# 4        Current account  Not specified  ...
# ...                  ...            ...  ...
# 1000093  Savings account         Single  ...
# 1000094  Savings account         Single  ...
# 1000095  Savings account         Single  ...
# 1000096  Savings account         Single  ...
# 1000097  Savings account         Single  ...
#
#                            ExcessSelected        CoverCategory  \
# 0                   Mobility - Windscreen           Windscreen
# 1                   Mobility - Windscreen           Windscreen
# 2                   Mobility - Windscreen           Windscreen
# 3        Mobility - Metered Taxis - R2000           Own damage
# 4        Mobility - Metered Taxis - R2000           Own damage
# ...                                   ...                  ...
# 1000093                         No excess          Third Party
# 1000094                         No excess          Third Party
# 1000095                         No excess          Third Party
# 1000096                         No excess  Passenger Liability
# 1000097                         No excess  Passenger Liability
#
#                    CoverType            CoverGroup              Section  \
# 0                 Windscreen  Comprehensive - Taxi  Motor Comprehensive
# 1                 Windscreen  Comprehensive - Taxi  Motor Comprehensive
# 2                 Windscreen  Comprehensive - Taxi  Motor Comprehensive
# 3                 Own Damage  Comprehensive - Taxi  Motor Comprehensive
# 4                 Own Damage  Comprehensive - Taxi  Motor Comprehensive
# ...                      ...                   ...                  ...
# 1000093          Third Party  Comprehensive - Taxi  Motor Comprehensive
# 1000094          Third Party  Comprehensive - Taxi  Motor Comprehensive
# 1000095          Third Party  Comprehensive - Taxi  Motor Comprehensive
# 1000096  Passenger Liability  Comprehensive - Taxi  Motor Comprehensive
# 1000097  Passenger Liability  Comprehensive - Taxi  Motor Comprehensive
#
#                                     Product StatutoryClass  StatutoryRiskType  \
# 0           Mobility Metered Taxis: Monthly     Commercial      IFRS Constant
# 1           Mobility Metered Taxis: Monthly     Commercial      IFRS Constant
# 2           Mobility Metered Taxis: Monthly     Commercial      IFRS Constant
# 3           Mobility Metered Taxis: Monthly     Commercial      IFRS Constant
# 4           Mobility Metered Taxis: Monthly     Commercial      IFRS Constant
# ...                                     ...            ...                ...
# 1000093  Mobility Commercial Cover: Monthly     Commercial      IFRS Constant
# 1000094  Mobility Commercial Cover: Monthly     Commercial      IFRS Constant
# 1000095  Mobility Commercial Cover: Monthly     Commercial      IFRS Constant
# 1000096  Mobility Commercial Cover: Monthly     Commercial      IFRS Constant
# 1000097  Mobility Commercial Cover: Monthly     Commercial      IFRS Constant
#
#         TotalPremium  TotalClaims
# 0          21.929825            0
# 1          21.929825            0
# 2           0.000000            0
# 3         512.848070            0
# 4           0.000000            0
# ...              ...          ...
# 1000093   347.235175            0
# 1000094   347.235175            0
# 1000095   347.235175            0
# 1000096     2.315000            0
# 1000097     2.315000            0
#
# [1000098 rows x 45 columns]

# %%
## Impute numercical data with mean
data_preprocessing.impute_numerical_data()
# Out:
#          UnderwrittenCoverID  PolicyID TransactionMonth  IsVATRegistered  \
# 0                     145249     12827    3/1/2015 0:00             True
# 1                     145249     12827    5/1/2015 0:00             True
# 2                     145249     12827    7/1/2015 0:00             True
# 3                     145255     12827    5/1/2015 0:00             True
# 4                     145255     12827    7/1/2015 0:00             True
# ...                      ...       ...              ...              ...
# 1000093                31520       389    4/1/2015 0:00            False
# 1000094                31520       389    6/1/2015 0:00            False
# 1000095                31520       389    8/1/2015 0:00            False
# 1000096                31519       389    7/1/2014 0:00            False
# 1000097                31519       389    2/1/2015 0:00            False
#
#                  LegalType Title Language                 Bank  \
# 0        Close Corporation    Mr  English  First National Bank
# 1        Close Corporation    Mr  English  First National Bank
# 2        Close Corporation    Mr  English  First National Bank
# 3        Close Corporation    Mr  English  First National Bank
# 4        Close Corporation    Mr  English  First National Bank
# ...                    ...   ...      ...                  ...
# 1000093         Individual    Mr  English            ABSA Bank
# 1000094         Individual    Mr  English            ABSA Bank
# 1000095         Individual    Mr  English            ABSA Bank
# 1000096         Individual    Mr  English            ABSA Bank
# 1000097         Individual    Mr  English            ABSA Bank
#
#              AccountType  MaritalStatus  ...  \
# 0        Current account  Not specified  ...
# 1        Current account  Not specified  ...
# 2        Current account  Not specified  ...
# 3        Current account  Not specified  ...
# 4        Current account  Not specified  ...
# ...                  ...            ...  ...
# 1000093  Savings account         Single  ...
# 1000094  Savings account         Single  ...
# 1000095  Savings account         Single  ...
# 1000096  Savings account         Single  ...
# 1000097  Savings account         Single  ...
#
#                            ExcessSelected        CoverCategory  \
# 0                   Mobility - Windscreen           Windscreen
# 1                   Mobility - Windscreen           Windscreen
# 2                   Mobility - Windscreen           Windscreen
# 3        Mobility - Metered Taxis - R2000           Own damage
# 4        Mobility - Metered Taxis - R2000           Own damage
# ...                                   ...                  ...
# 1000093                         No excess          Third Party
# 1000094                         No excess          Third Party
# 1000095                         No excess          Third Party
# 1000096                         No excess  Passenger Liability
# 1000097                         No excess  Passenger Liability
#
#                    CoverType            CoverGroup              Section  \
# 0                 Windscreen  Comprehensive - Taxi  Motor Comprehensive
# 1                 Windscreen  Comprehensive - Taxi  Motor Comprehensive
# 2                 Windscreen  Comprehensive - Taxi  Motor Comprehensive
# 3                 Own Damage  Comprehensive - Taxi  Motor Comprehensive
# 4                 Own Damage  Comprehensive - Taxi  Motor Comprehensive
# ...                      ...                   ...                  ...
# 1000093          Third Party  Comprehensive - Taxi  Motor Comprehensive
# 1000094          Third Party  Comprehensive - Taxi  Motor Comprehensive
# 1000095          Third Party  Comprehensive - Taxi  Motor Comprehensive
# 1000096  Passenger Liability  Comprehensive - Taxi  Motor Comprehensive
# 1000097  Passenger Liability  Comprehensive - Taxi  Motor Comprehensive
#
#                                     Product StatutoryClass  StatutoryRiskType  \
# 0           Mobility Metered Taxis: Monthly     Commercial      IFRS Constant
# 1           Mobility Metered Taxis: Monthly     Commercial      IFRS Constant
# 2           Mobility Metered Taxis: Monthly     Commercial      IFRS Constant
# 3           Mobility Metered Taxis: Monthly     Commercial      IFRS Constant
# 4           Mobility Metered Taxis: Monthly     Commercial      IFRS Constant
# ...                                     ...            ...                ...
# 1000093  Mobility Commercial Cover: Monthly     Commercial      IFRS Constant
# 1000094  Mobility Commercial Cover: Monthly     Commercial      IFRS Constant
# 1000095  Mobility Commercial Cover: Monthly     Commercial      IFRS Constant
# 1000096  Mobility Commercial Cover: Monthly     Commercial      IFRS Constant
# 1000097  Mobility Commercial Cover: Monthly     Commercial      IFRS Constant
#
#         TotalPremium  TotalClaims
# 0          21.929825            0
# 1          21.929825            0
# 2           0.000000            0
# 3         512.848070            0
# 4           0.000000            0
# ...              ...          ...
# 1000093   347.235175            0
# 1000094   347.235175            0
# 1000095   347.235175            0
# 1000096     2.315000            0
# 1000097     2.315000            0
#
# [1000098 rows x 45 columns]

# %%
# duplicated values
df.duplicated().sum()
# Out:
# np.int64(75)

# %%
# Drop Duplicates
df.drop_duplicates(inplace=True)

# %%
# Drop rows with missing values
df.dropna()
# Out:
#          UnderwrittenCoverID  PolicyID TransactionMonth  IsVATRegistered  \
# 0                     145249     12827    3/1/2015 0:00             True
# 1                     145249     12827    5/1/2015 0:00             True
# 2                     145249     12827    7/1/2015 0:00             True
# 3                     145255     12827    5/1/2015 0:00             True
# 4                     145255     12827    7/1/2015 0:00             True
# ...                      ...       ...              ...              ...
# 1000093                31520       389    4/1/2015 0:00            False
# 1000094                31520       389    6/1/2015 0:00            False
# 1000095                31520       389    8/1/2015 0:00            False
# 1000096                31519       389    7/1/2014 0:00            False
# 1000097                31519       389    2/1/2015 0:00            False
#
#                  LegalType Title Language                 Bank  \
# 0        Close Corporation    Mr  English  First National Bank
# 1        Close Corporation    Mr  English  First National Bank
# 2        Close Corporation    Mr  English  First National Bank
# 3        Close Corporation    Mr  English  First National Bank
# 4        Close Corporation    Mr  English  First National Bank
# ...                    ...   ...      ...                  ...
# 1000093         Individual    Mr  English            ABSA Bank
# 1000094         Individual    Mr  English            ABSA Bank
# 1000095         Individual    Mr  English            ABSA Bank
# 1000096         Individual    Mr  English            ABSA Bank
# 1000097         Individual    Mr  English            ABSA Bank
#
#              AccountType  MaritalStatus  ...  \
# 0        Current account  Not specified  ...
# 1        Current account  Not specified  ...
# 2        Current account  Not specified  ...
# 3        Current account  Not specified  ...
# 4        Current account  Not specified  ...
# ...                  ...            ...  ...
# 1000093  Savings account         Single  ...
# 1000094  Savings account         Single  ...
# 1000095  Savings account         Single  ...
# 1000096  Savings account         Single  ...
# 1000097  Savings account         Single  ...
#
#                            ExcessSelected        CoverCategory  \
# 0                   Mobility - Windscreen           Windscreen
# 1                   Mobility - Windscreen           Windscreen
# 2                   Mobility - Windscreen           Windscreen
# 3        Mobility - Metered Taxis - R2000           Own damage
# 4        Mobility - Metered Taxis - R2000           Own damage
# ...                                   ...                  ...
# 1000093                         No excess          Third Party
# 1000094                         No excess          Third Party
# 1000095                         No excess          Third Party
# 1000096                         No excess  Passenger Liability
# 1000097                         No excess  Passenger Liability
#
#                    CoverType            CoverGroup              Section  \
# 0                 Windscreen  Comprehensive - Taxi  Motor Comprehensive
# 1                 Windscreen  Comprehensive - Taxi  Motor Comprehensive
# 2                 Windscreen  Comprehensive - Taxi  Motor Comprehensive
# 3                 Own Damage  Comprehensive - Taxi  Motor Comprehensive
# 4                 Own Damage  Comprehensive - Taxi  Motor Comprehensive
# ...                      ...                   ...                  ...
# 1000093          Third Party  Comprehensive - Taxi  Motor Comprehensive
# 1000094          Third Party  Comprehensive - Taxi  Motor Comprehensive
# 1000095          Third Party  Comprehensive - Taxi  Motor Comprehensive
# 1000096  Passenger Liability  Comprehensive - Taxi  Motor Comprehensive
# 1000097  Passenger Liability  Comprehensive - Taxi  Motor Comprehensive
#
#                                     Product StatutoryClass  StatutoryRiskType  \
# 0           Mobility Metered Taxis: Monthly     Commercial      IFRS Constant
# 1           Mobility Metered Taxis: Monthly     Commercial      IFRS Constant
# 2           Mobility Metered Taxis: Monthly     Commercial      IFRS Constant
# 3           Mobility Metered Taxis: Monthly     Commercial      IFRS Constant
# 4           Mobility Metered Taxis: Monthly     Commercial      IFRS Constant
# ...                                     ...            ...                ...
# 1000093  Mobility Commercial Cover: Monthly     Commercial      IFRS Constant
# 1000094  Mobility Commercial Cover: Monthly     Commercial      IFRS Constant
# 1000095  Mobility Commercial Cover: Monthly     Commercial      IFRS Constant
# 1000096  Mobility Commercial Cover: Monthly     Commercial      IFRS Constant
# 1000097  Mobility Commercial Cover: Monthly     Commercial      IFRS Constant
#
#         TotalPremium  TotalClaims
# 0          21.929825            0
# 1          21.929825            0
# 2           0.000000            0
# 3         512.848070            0
# 4           0.000000            0
# ...              ...          ...
# 1000093   347.235175            0
# 1000094   347.235175            0
# 1000095   347.235175            0
# 1000096     2.315000            0
# 1000097     2.315000            0
#
# [999469 rows x 45 columns]

# %%
## Check for missing values
df.isna().sum()
# Out:
# UnderwrittenCoverID           0
# PolicyID                      0
# TransactionMonth              0
# IsVATRegistered               0
# LegalType                     0
# Title                         0
# Language                      0
# Bank                          0
# AccountType                   0
# MaritalStatus                 0
# Gender                        0
# Country                       0
# Province                      0
# PostalCode                    0
# MainCrestaZone                0
# SubCrestaZone                 0
# ItemType                      0
# mmcode                        0
# VehicleType                   0
# RegistrationYear              0
# make                          0
# Model                         0
# Cylinders                     0
# cubiccapacity                 0
# kilowatts                     0
# bodytype                      0
# NumberOfDoors                 0
# VehicleIntroDate            552
# AlarmImmobiliser              0
# TrackingDevice                0
# CapitalOutstanding            2
# NewVehicle                    0
# SumInsured                    0
# TermFrequency                 0
# CalculatedPremiumPerTerm      0
# ExcessSelected                0
# CoverCategory                 0
# CoverType                     0
# CoverGroup                    0
# Section                       0
# Product                       0
# StatutoryClass                0
# StatutoryRiskType             0
# TotalPremium                  0
# TotalClaims                   0
# dtype: int64

# %%
## Feature Engineering

## Add a Profit Column
df['Profit'] = df['TotalPremium'] - df['TotalClaims']

## Add Claim to Premium ratio
df['claim_to_premium_ratio'] = df['TotalClaims']/(df['TotalPremium']+1)

# %%
# Convert 'TransactionMonth' 
df['TransactionMonth'] = pd.to_datetime(df['TransactionMonth'], errors='coerce')
df['VehicleIntroDate'] = pd.to_datetime(df['VehicleIntroDate'], errors='coerce')

# Extract features from datetime columns
df['TransactionMonth_Year'] = df['TransactionMonth'].dt.year
df['TransactionMonth_Month'] = df['TransactionMonth'].dt.month
df['VehicleIntroDate_Year'] = df['VehicleIntroDate'].dt.year
df['VehicleIntroDate_Month'] = df['VehicleIntroDate'].dt.month
df = df.drop(columns=['TransactionMonth', 'VehicleIntroDate'])
# Out:
# C:\Users\wasihunt\AppData\Local\Temp\ipykernel_5620\1191713088.py:3: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df['VehicleIntroDate'] = pd.to_datetime(df['VehicleIntroDate'], errors='coerce')

# %%
df.dropna(inplace=True)

# %%
categorical_columns = df.select_dtypes(include=['object','bool']).columns.tolist()
df_encoded = pd.get_dummies(df, columns = categorical_columns, drop_first=True)
df_encoded
# Out:
#          UnderwrittenCoverID  PolicyID  PostalCode      mmcode  \
# 0                     145249     12827        1459  44069150.0
# 1                     145249     12827        1459  44069150.0
# 2                     145249     12827        1459  44069150.0
# 3                     145255     12827        1459  44069150.0
# 4                     145255     12827        1459  44069150.0
# ...                      ...       ...         ...         ...
# 1000093                31520       389        7493   4614100.0
# 1000094                31520       389        7493   4614100.0
# 1000095                31520       389        7493   4614100.0
# 1000096                31519       389        7493   4614100.0
# 1000097                31519       389        7493   4614100.0
#
#          RegistrationYear  Cylinders  cubiccapacity  kilowatts  NumberOfDoors  \
# 0                    2004        6.0         2597.0      130.0            4.0
# 1                    2004        6.0         2597.0      130.0            4.0
# 2                    2004        6.0         2597.0      130.0            4.0
# 3                    2004        6.0         2597.0      130.0            4.0
# 4                    2004        6.0         2597.0      130.0            4.0
# ...                   ...        ...            ...        ...            ...
# 1000093              2013        4.0         2693.0      110.0            4.0
# 1000094              2013        4.0         2693.0      110.0            4.0
# 1000095              2013        4.0         2693.0      110.0            4.0
# 1000096              2013        4.0         2693.0      110.0            4.0
# 1000097              2013        4.0         2693.0      110.0            4.0
#
#          CapitalOutstanding  ...  CoverGroup_Standalone passenger liability  \
# 0                  119300.0  ...                                      False
# 1                  119300.0  ...                                      False
# 2                  119300.0  ...                                      False
# 3                  119300.0  ...                                      False
# 4                  119300.0  ...                                      False
# ...                     ...  ...                                        ...
# 1000093                 0.0  ...                                      False
# 1000094                 0.0  ...                                      False
# 1000095                 0.0  ...                                      False
# 1000096                 0.0  ...                                      False
# 1000097                 0.0  ...                                      False
#
#          CoverGroup_Third Party Only  CoverGroup_Trailer  \
# 0                              False               False
# 1                              False               False
# 2                              False               False
# 3                              False               False
# 4                              False               False
# ...                              ...                 ...
# 1000093                        False               False
# 1000094                        False               False
# 1000095                        False               False
# 1000096                        False               False
# 1000097                        False               False
#
#          Section_Motor Comprehensive  Section_Optional Extended Covers  \
# 0                               True                             False
# 1                               True                             False
# 2                               True                             False
# 3                               True                             False
# 4                               True                             False
# ...                              ...                               ...
# 1000093                         True                             False
# 1000094                         True                             False
# 1000095                         True                             False
# 1000096                         True                             False
# 1000097                         True                             False
#
#          Section_Standalone passenger liability  \
# 0                                         False
# 1                                         False
# 2                                         False
# 3                                         False
# 4                                         False
# ...                                         ...
# 1000093                                   False
# 1000094                                   False
# 1000095                                   False
# 1000096                                   False
# 1000097                                   False
#
#          Section_Third party or third party, fire and theft only  \
# 0                                                    False
# 1                                                    False
# 2                                                    False
# 3                                                    False
# 4                                                    False
# ...                                                    ...
# 1000093                                              False
# 1000094                                              False
# 1000095                                              False
# 1000096                                              False
# 1000097                                              False
#
#          Product_Mobility Commercial Cover: Monthly  \
# 0                                             False
# 1                                             False
# 2                                             False
# 3                                             False
# 4                                             False
# ...                                             ...
# 1000093                                        True
# 1000094                                        True
# 1000095                                        True
# 1000096                                        True
# 1000097                                        True
#
#          Product_Mobility Metered Taxis: Monthly  \
# 0                                           True
# 1                                           True
# 2                                           True
# 3                                           True
# 4                                           True
# ...                                          ...
# 1000093                                    False
# 1000094                                    False
# 1000095                                    False
# 1000096                                    False
# 1000097                                    False
#
#          Product_Standalone Passenger Liability
# 0                                         False
# 1                                         False
# 2                                         False
# 3                                         False
# 4                                         False
# ...                                         ...
# 1000093                                   False
# 1000094                                   False
# 1000095                                   False
# 1000096                                   False
# 1000097                                   False
#
# [999469 rows x 668 columns]

# %%
df_encoded = df_encoded.astype({col: 'uint8' for col in df_encoded.select_dtypes('bool').columns})

# %%
df_encoded.dtypes
# Out:
# UnderwrittenCoverID                                          int64
# PolicyID                                                     int64
# PostalCode                                                   int64
# mmcode                                                     float64
# RegistrationYear                                             int64
#                                                             ...
# Section_Standalone passenger liability                       uint8
# Section_Third party or third party, fire and theft only      uint8
# Product_Mobility Commercial Cover: Monthly                   uint8
# Product_Mobility Metered Taxis: Monthly                      uint8
# Product_Standalone Passenger Liability                       uint8
# Length: 668, dtype: object

# %% [markdown]
# ### ***Train Test Split***

# %%
## Define target and features
X = df_encoded.drop(['TotalPremium', 'TotalClaims'], axis=1)
y_premium = df_encoded['TotalPremium']
y_claims = df_encoded['TotalClaims']


# Split data for TotalPremium
X_train_premium, X_test_premium, y_train_premium, y_test_premium = train_test_split(X, y_premium, test_size=0.2, random_state=42)

# Split data for TotalClaims
X_train_claims, X_test_claims, y_train_claims, y_test_claims = train_test_split(X, y_claims, test_size=0.2, random_state=42)

# %% [markdown]
# ### ***Model Building***

# %% [markdown]
# #### ***Linear Regression Model***

# %% [markdown]
# ##### ***Premium Prediction***

# %%
# Model for TotalPremium
model_premium_lr = LinearRegression()
model_premium_lr.fit(X_train_premium, y_train_premium)
y_pred_premium_lr = model_premium_lr.predict(X_test_premium)

# %%
# Calculate Metrics
mse_premium_lr = mean_squared_error(y_test_premium, y_pred_premium_lr)
mae_premium_lr = mean_absolute_error(y_test_premium, y_pred_premium_lr)
r2_premium_lr = r2_score(y_test_premium, y_pred_premium_lr)

# Evaluate
print(f"TotalPremium - MSE: {mse_premium_lr}, R^2: {r2_premium_lr}, MAE: {mae_premium_lr}")
# Out:
# TotalPremium - MSE: 10838.291748764714, R^2: 0.5645720437648727, MAE: 50.93459588510656

# %% [markdown]
# ##### ***SHAP Explainer***

# %%
explainer = shap.Explainer(model_premium_lr, X_train_premium)
shap_values = explainer(X_test_premium)

# %%
## Summary Plot
shap.summary_plot(shap_values, X_test_premium)

# %%
## Visualize how each feature conributes to a single prediction
shap.force_plot(explainer.expected_value, shap_values[0, :], X_test_premium.iloc[0])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[45], line 2
#       1 ## Visualize how each feature conributes to a single prediction
# ----> 2 shap.force_plot(explainer.expected_value, shap_values[0, :], X_test_premium.iloc[0])
#
# File d:\Personal Files\KIAM Notebooks\KIAM-Week3\myenv\lib\site-packages\shap\plots\_force.py:138, in force(base_value, shap_values, features, feature_names, out_names, link, plot_cmap, matplotlib, show, figsize, ordering_keys, ordering_keys_time_format, text_rotation, contribution_threshold)
#     135 link = convert_to_link(link)
#     137 if type(shap_values) != np.ndarray:
# --> 138     return visualize(shap_values)
#     140 # convert from a DataFrame or other types
#     141 if isinstance(features, pd.DataFrame):
#
# File d:\Personal Files\KIAM Notebooks\KIAM-Week3\myenv\lib\site-packages\shap\plots\_force.py:428, in visualize(e, plot_cmap, matplotlib, figsize, show, ordering_keys, ordering_keys_time_format, text_rotation, min_perc)
#     421     return AdditiveForceArrayVisualizer(
#     422         e,
#     423         plot_cmap=plot_cmap,
#     424         ordering_keys=ordering_keys,
#     425         ordering_keys_time_format=ordering_keys_time_format,
#     426     )
#     427 else:
# --> 428     raise ValueError("visualize() can only display Explanation objects (or arrays of them)!")
#
# ValueError: visualize() can only display Explanation objects (or arrays of them)!

# %%
## Show relationship between Premium and Shap values
shap.dependence_plot("TotalPremium", shap_values, X_test_premium)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[46], line 2
#       1 ## Show relationship between Premium and Shap values
# ----> 2 shap.dependence_plot("TotalPremium", shap_values, X_test_premium)
#
# File d:\Personal Files\KIAM Notebooks\KIAM-Week3\myenv\lib\site-packages\shap\plots\_scatter.py:567, in dependence_legacy(ind, shap_values, features, feature_names, display_features, interaction_index, color, axis_color, cmap, dot_size, x_jitter, alpha, title, xmin, xmax, ax, show, ymin, ymax)
#     564 if len(features.shape) == 1:
#     565     features = np.reshape(features, (len(features), 1))
# --> 567 ind = convert_name(ind, shap_values, feature_names)
#     569 # guess what other feature as the stongest interaction with the plotted feature
#     570 if not hasattr(ind, "__len__"):
#
# File d:\Personal Files\KIAM Notebooks\KIAM-Week3\myenv\lib\site-packages\shap\utils\_general.py:46, in convert_name(ind, shap_values, input_names)
#      44         return "sum()"
#      45     else:
# ---> 46         raise ValueError("Could not find feature named: " + ind)
#      47 else:
#      48     return nzinds[0]
#
# ValueError: Could not find feature named: TotalPremium

# %% [markdown]
# #### ***Claim Prediction***

# %%
# Model for TotalClaims
model_claims_lr = LinearRegression()
model_claims_lr.fit(X_train_claims, y_train_claims)
y_pred_claims_lr = model_claims_lr.predict(X_test_claims)

# %%
# Calculate metrics
mse_claims_lr = mean_squared_error(y_test_claims, y_pred_claims_lr)
mae_claims_lr = mean_absolute_error(y_test_claims, y_pred_claims_lr)
r2_claims_lr = r2_score(y_test_claims, y_pred_claims_lr)

print(f"TotalPremium - MSE: {mse_claims_lr}, R^2: {r2_claims_lr}, MAE: {mae_claims_lr}")
# Out:
# TotalPremium - MSE: 10838.291748764523, R^2: 0.9965166833864757, MAE: 50.934595885066244

# %% [markdown]
# ##### ***SHAP Explainer***

# %%
## Initialize Shap explainer
explainer = shap.Explainer(model_claims_lr, X_train_claims)
shap_values = explainer(X_test_claims)

# %%
## Summary Plot
shap.summary_plot(shap_values, X_test_claims,plot_type='bar')

# %%
# Waterfall plot for the first observation
shap.waterfall_plot(shap_values[0])

# %%
## Visualize how each feature conributes to a single prediction
shap.force_plot(explainer.expected_value, shap_values[0], X_test_claims.iloc[0, :], matplotlib=True)

# %%
## Show relationship between Premium and Shap values
shap.dependence_plot("ShellWeight", shap_values, X_test_claims)

# %% [markdown]
# ### ***Decision Trees Model***

# %% [markdown]
# ##### ***Premium Prediciton***

# %%
# Model for TotalPremium
model_premium_dt = DecisionTreeRegressor()
model_premium_dt.fit(X_train_premium, y_train_premium)
y_pred_premium_dt = model_premium_dt.predict(X_test_premium)

# %%
# Calculate Metrics
mse_premium_dt = mean_squared_error(y_test_premium, y_pred_premium_dt)
mae_premium_dt = mean_absolute_error(y_test_premium, y_pred_premium_dt)
r2_premium_dt = r2_score(y_test_premium, y_pred_premium_dt)

print(f"TotalPremium - MSE: {mse_premium_dt}, R^2: {r2_premium_dt}, MAE: {mae_premium_dt}")
# Out:
# TotalPremium - MSE: 10.849891342891304, R^2: 0.9995641060305147, MAE: 0.03702292544123275

# %% [markdown]
# #### ***SHAP Explainer***

# %%
explainer = shap.Explainer(model_premium_dt, X_train_premium)
shap_values = explainer(X_test_premium)

# %%
## Summary Plot
shap.summary_plot(shap_values, X_test_premium)

# %%
## Visualize how each feature conributes to a single prediction
shap.force_plot(explainer.expected_value, shap_values[0, :], X_test_premium.iloc[0])

# %%
## Show relationship between Premium and Shap values
shap.dependence_plot("TotalPremium", shap_values, X_test_premium)

# %%
X_train_premium.dtypes

# %% [markdown]
# ##### ***Claim Prediction***

# %%
# Model for TotalClaims
model_claims_dt = DecisionTreeRegressor()
model_claims_dt.fit(X_train_claims, y_train_claims)
y_pred_claims_dt = model_claims_dt.predict(X_test_claims)

# %%
# Calculate Metrics
mse_claims_dt = mean_squared_error(y_test_claims, y_pred_claims_dt)
mae_claims_dt = mean_absolute_error(y_test_claims, y_pred_claims_dt)
r2_claims_dt = r2_score(y_test_claims, y_pred_claims_dt)

print(f"TotalPremium - MSE: {mse_claims_dt}, R^2: {r2_claims_dt}, MAE: {mae_claims_dt}")

# %% [markdown]
# ### ***Random Forest Model***

# %%
# Model for TotalPremium
model_premium_rf = RandomForestRegressor()
model_premium_rf.fit(X_train_premium, y_train_premium)
y_pred_premium_rf = model_premium_rf.predict(X_test_premium)

# %%
# Calculate Metrics
mse_premium_rf = mean_squared_error(y_test_premium, y_pred_premium_rf)
mae_premium_rf = mean_absolute_error(y_test_premium, y_pred_premium_rf)
r2_premium_rf = r2_score(y_test_premium, y_pred_premium_rf)

print(f"TotalPremium - MSE: {mse_premium_rf}, R^2: {r2_premium_rf}, MAE: {mae_premium_rf}")

# %%
# Model for TotalClaims
model_claims_rf = RandomForestRegressor()
model_claims_rf.fit(X_train_claims, y_train_claims)
y_pred_claims_rf = model_claims_rf.predict(X_test_claims)

# %%
# Calculate Metrics
mse_claims_rf = mean_squared_error(y_test_claims, y_pred_claims_rf)
mae_claims_rf = mean_absolute_error(y_test_claims, y_pred_claims_rf)
r2_claims_rf = r2_score(y_test_claims, y_pred_claims_rf)

print(f"TotalPremium - MSE: {mse_claims_rf}, R^2: {r2_claims_rf}, MAE: {mae_claims_rf}")

# %% [markdown]
# ### ***XGboost Model***

# %%
# Model for TotalPremium
model_premium_xgb = xgb.XGBRegressor()
model_premium_xgb.fit(X_train_premium, y_train_premium)
y_pred_premium_xgb = model_premium_xgb.predict(X_test_premium)

# %%
# Calculate Metrics
mse_premium_xgb = mean_squared_error(y_test_premium, y_pred_premium_xgb)
mae_premium_xgb = mean_absolute_error(y_test_premium, y_pred_premium_xgb)
r2_premium_xgb = r2_score(y_test_premium, y_pred_premium_xgb)

print(f"TotalPremium - MSE: {mse_premium_xgb}, R^2: {r2_premium_xgb}, MAE: {mae_premium_xgb}")

# %%
# Model for TotalClaims
model_claims_xgb = xgb.XGBRegressor()
model_claims_xgb.fit(X_train_claims, y_train_claims)
y_pred_claims_xgb = model_claims_xgb.predict(X_test_claims)

# %%
# Calculate Metrics
mse_claims_xgb = mean_squared_error(y_test_claims, y_pred_claims_xgb)
mae_claims_xgb = mean_absolute_error(y_test_claims, y_pred_claims_xgb)
r2_claims_xgb = r2_score(y_test_claims, y_pred_claims_xgb)

print(f"TotalPremium - MSE: {mse_claims_xgb}, R^2: {r2_claims_xgb}, MAE: {mae_claims_xgb}")

# %% [markdown]
# ### ***Model Comparison***

# %%
# Create a summary of model performance
results = pd.DataFrame({
    'Model': ['Linear Regression', 'Decision Tree', 'Random Forest', 'XGBoost'],
    'TotalPremium_MSE': [
        mean_squared_error(y_test_premium, y_pred_premium_lr),
        mean_squared_error(y_test_premium, y_pred_premium_dt),
        mean_squared_error(y_test_premium, y_pred_premium_rf),
        mean_squared_error(y_test_premium, y_pred_premium_xgb)
    ],
    'TotalClaims_MSE': [
    mean_squared_error(y_test_claims, y_pred_claims_lr),
    mean_squared_error(y_test_claims, y_pred_claims_dt),
    mean_squared_error(y_test_claims, y_pred_claims_rf),
    mean_squared_error(y_test_claims, y_pred_claims_xgb)
],
'TotalPremium_R2': [
    r2_score(y_test_premium, y_pred_premium_lr),
    r2_score(y_test_premium, y_pred_premium_dt),
    r2_score(y_test_premium, y_pred_premium_rf),
    r2_score(y_test_premium, y_pred_premium_xgb)
],
'TotalClaims_R2': [
    r2_score(y_test_claims, y_pred_claims_lr),
    r2_score(y_test_claims, y_pred_claims_dt),
    r2_score(y_test_claims, y_pred_claims_rf),
    r2_score(y_test_claims, y_pred_claims_xgb)
]
})

results
